# %%
pip install pandas numpy scikit-learn matplotlib tensorflow streamlit
# Out:
# Requirement already satisfied: pandas in d:\anaconda\envs\myenv\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in d:\anaconda\envs\myenv\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in d:\anaconda\envs\myenv\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in d:\anaconda\envs\myenv\lib\site-packages (3.9.4)
# Requirement already satisfied: tensorflow in d:\anaconda\envs\myenv\lib\site-packages (2.15.0)
# Requirement already satisfied: streamlit in d:\anaconda\envs\myenv\lib\site-packages (1.50.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in d:\anaconda\envs\myenv\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\envs\myenv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\envs\myenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\anaconda\envs\myenv\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.8)
# Requirement already satisfied: setuptools in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda\envs\myenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\anaconda\envs\myenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\envs\myenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\envs\myenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\envs\myenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\envs\myenv\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\anaconda\envs\myenv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.6.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: pyarrow>=7.0 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in d:\anaconda\envs\myenv\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in d:\anaconda\envs\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda\envs\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in d:\anaconda\envs\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.5.0)
# Requirement already satisfied: colorama in d:\anaconda\envs\myenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\anaconda\envs\myenv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\anaconda\envs\myenv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\envs\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.45.1)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda\envs\myenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\envs\myenv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\anaconda\envs\myenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (8.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\envs\myenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
# Out:
# WARNING:tensorflow:From D:\Anaconda\envs\myenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('train.csv', header=0, names=['class', 'title', 'description'])
df['text'] = df['title'] + ' ' + df['description']

# %%
print(df['class'].unique())
# Out:
# [3 4 2 1]

# %%
df['class'] = df['class'].astype(int)
df['class_idx'] = df['class'] - 1
print(df['class_idx'].unique())
# Out:
# [2 3 1 0]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['class_idx'] = encoder.fit_transform(df['class'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['class_idx'], test_size=0.2, random_state=42)

# %%
max_words = 10000
max_len = 100
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)

# %%
import pickle

with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# %%
num_classes = len(set(y_train))

model = Sequential([
    Embedding(max_words, 128, input_length=max_len),
    LSTM(64, return_sequences=False),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = model.fit(X_train_pad, y_train, epochs=5, batch_size=128, validation_split=0.1)
model.save("agnews_lstm_model.h5")
# Out:
# Epoch 1/5
# 675/675 [==============================] - 97s 139ms/step - loss: 0.4190 - accuracy: 0.8594 - val_loss: 0.2702 - val_accuracy: 0.9111
# Epoch 2/5
# 675/675 [==============================] - 90s 134ms/step - loss: 0.2369 - accuracy: 0.9267 - val_loss: 0.2651 - val_accuracy: 0.9135
# Epoch 3/5
# 675/675 [==============================] - 91s 135ms/step - loss: 0.1957 - accuracy: 0.9383 - val_loss: 0.2830 - val_accuracy: 0.9116
# Epoch 4/5
# 675/675 [==============================] - 82s 122ms/step - loss: 0.1680 - accuracy: 0.9456 - val_loss: 0.3098 - val_accuracy: 0.9027
# Epoch 5/5
# 675/675 [==============================] - 88s 131ms/step - loss: 0.1458 - accuracy: 0.9520 - val_loss: 0.3261 - val_accuracy: 0.9027
# D:\Anaconda\envs\myenv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
loss, accuracy = model.evaluate(X_test_pad, y_test)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 750/750 [==============================] - 11s 13ms/step - loss: 0.3299 - accuracy: 0.9030
# Test Accuracy: 0.9030
